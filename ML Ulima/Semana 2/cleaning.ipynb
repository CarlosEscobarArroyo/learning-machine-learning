# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('/Users/carlosescobar/Desktop/Machine Learning/ML Ulima/Semana 1/wine.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65499 entries, 0 to 65498
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             65499 non-null  int64
#  1   country                65467 non-null  object
#  2   description            65499 non-null  object
#  3   designation            46588 non-null  object
#  4   points                 65499 non-null  int64
#  5   price                  60829 non-null  float64
#  6   province               65467 non-null  object
#  7   region_1               54744 non-null  object
#  8   region_2               25170 non-null  object
#  9   taster_name            51856 non-null  object
#  10  taster_twitter_handle  49467 non-null  object
#  11  title                  65499 non-null  object
#  12  variety                65499 non-null  object
#  13  winery                 65499 non-null  object
# ...

# %%
df.iloc[100] #Sería el elemento 101
# Out:
# Unnamed: 0                                                             100
# country                                                                 US
# description              Fresh apple, lemon and pear flavors are accent...
# designation                                                            NaN
# points                                                                  88
# price                                                                 18.0
# province                                                          New York
# region_1                                                      Finger Lakes
# region_2                                                      Finger Lakes
# taster_name                                             Anna Lee C. Iijima
# taster_twitter_handle                                                  NaN
# title                               Ventosa 2015 Pinot Gris (Finger Lakes)
# ...

# %%
df.iloc[:3,0]
#Las primeras 3 filas y la primera columna
#Desde 0. hasta 3...
# Out:
# 0    0
# 1    1
# 2    2
# Name: Unnamed: 0, dtype: int64

# %%
df.iloc[-3:,:2]
#Desde los 3 ultimos, hasta el final
# Out:
#        Unnamed: 0 country
# 65496       65496      US
# 65497       65497      US
# 65498       65498   Spain

# %%
columnas = df.columns

# %%
columnas[-3:]
# Out:
# Index(['title', 'variety', 'winery'], dtype='object')

# %%
columnas
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
df.set_index('variety')
# Out:
#                     Unnamed: 0    country  \
# variety
# White Blend                  0      Italy
# Portuguese Red               1   Portugal
# Pinot Gris                   2         US
# Riesling                     3         US
# Pinot Noir                   4         US
# ...                        ...        ...
# Chardonnay               65494     France
# Cabernet Sauvignon       65495  Australia
# Sauvignon Blanc          65496         US
# Primitivo                65497         US
# Sherry                   65498      Spain
#
#                                                           description  \
# variety
# White Blend         Aromas include tropical fruit, broom, brimston...
# Portuguese Red      This is ripe and fruity, a wine that is smooth...
# Pinot Gris          Tart and snappy, the flavors of lime flesh and...
# Riesling            Pineapple rind, lemon pith and orange blossom ...
# Pinot Noir          Much like the regular bottling from 2012, this...
# ...

# %%
filtros = (df['country'] == 'Italy') & (df['price'] > 100) & (df['points'] > 80)
data_filtrada = df[filtros]

# %%
data_filtrada
# Out:
#        Unnamed: 0 country                                        description  \
# 350           350   Italy  After a few minutes in the glass, this stunnin...
# 739           739   Italy  Roasted coffee bean and menthol aromas lead th...
# 1077         1077   Italy  This savory, firmly structured, full-bodied re...
# 1452         1452   Italy  Underbrush, truffle, crushed herb and ripe bla...
# 1454         1454   Italy  Baked plum, baking spice, blue flower and pipe...
# ...           ...     ...                                                ...
# 65216       65216   Italy  This lovely riserva delivers dark layers of ch...
# 65218       65218   Italy  You'll love the pretty garnet color of this ri...
# 65219       65219   Italy  Here's a beautiful ensemble of bright cherry a...
# 65221       65221   Italy  Sometimes an annata Brunello can score higher ...
# 65224       65224   Italy  Smoky ash and brimstone give this wine an eleg...
#
# ...

# %%
df.price #Es lo mismo que df['price']
# Out:
# 0         NaN
# 1        15.0
# 2        14.0
# 3        13.0
# 4        65.0
#          ...
# 65494    45.0
# 65495    22.0
# 65496    20.0
# 65497    31.0
# 65498    10.0
# Name: price, Length: 65499, dtype: float64

# %%
df.price.describe()
# Out:
# count    60829.000000
# mean        35.232932
# std         39.477858
# min          4.000000
# 25%         17.000000
# 50%         25.000000
# 75%         42.000000
# max       2500.000000
# Name: price, dtype: float64

# %%
filtro = (df['price'] < 4)
df[filtro]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country, description, designation, points, price, province, region_1, region_2, taster_name, taster_twitter_handle, title, variety, winery]
# Index: []

# %%
df['country'].describe()
# Out:
# count     65467
# unique       41
# top          US
# freq      27177
# Name: country, dtype: object

# %%
df['variety'].describe()
# Out:
# count          65499
# unique           590
# top       Pinot Noir
# freq            6657
# Name: variety, dtype: object

# %%
df.variety.value_counts()
# Out:
# variety
# Pinot Noir                  6657
# Chardonnay                  5869
# Cabernet Sauvignon          4785
# Red Blend                   4552
# Bordeaux-style Red Blend    3443
#                             ...
# Irsai Oliver                   1
# Baga-Touriga Nacional          1
# Muscatel                       1
# Karasakiz                      1
# Misket                         1
# Name: count, Length: 590, dtype: int64

# %%
filtros = (df['variety'] == 'Chardonnay')
df[filtros].describe()
# Out:
#          Unnamed: 0       points        price
# count   5869.000000  5869.000000  5533.000000
# mean   33309.831317    88.358664    35.207482
# std    18938.180250     3.232630    40.290763
# min       14.000000    80.000000     4.000000
# 25%    16763.000000    86.000000    18.000000
# 50%    33710.000000    88.000000    27.000000
# 75%    49649.000000    91.000000    40.000000
# max    65494.000000    99.000000   886.000000

# %%
df['soles'] = df['price']*3.71

# %%
df['price'].map(lambda x: x*2)
# Out:
# 0          NaN
# 1         30.0
# 2         28.0
# 3         26.0
# 4        130.0
#          ...
# 65494     90.0
# 65495     44.0
# 65496     40.0
# 65497     62.0
# 65498     20.0
# Name: price, Length: 65499, dtype: float64

# %%
df['country'].map(lambda x: str(x) + ' pais')
# Out:
# 0            Italy pais
# 1         Portugal pais
# 2               US pais
# 3               US pais
# 4               US pais
#               ...
# 65494       France pais
# 65495    Australia pais
# 65496           US pais
# 65497           US pais
# 65498        Spain pais
# Name: country, Length: 65499, dtype: object

# %%
df['country'].map(lambda x: f'{x} XDDD')
# Out:
# 0            Italy XDDD
# 1         Portugal XDDD
# 2               US XDDD
# 3               US XDDD
# 4               US XDDD
#               ...
# 65494       France XDDD
# 65495    Australia XDDD
# 65496           US XDDD
# 65497           US XDDD
# 65498        Spain XDDD
# Name: country, Length: 65499, dtype: object

# %%
def peruano(row):
    if row['country'] == 'Peru':
        return 'Peruano'
    else:
        return 'Extranjero'
    
df.apply(peruano, axis='columns')
# Out:
# 0        Extranjero
# 1        Extranjero
# 2        Extranjero
# 3        Extranjero
# 4        Extranjero
#             ...
# 65494    Extranjero
# 65495    Extranjero
# 65496    Extranjero
# 65497    Extranjero
# 65498    Extranjero
# Length: 65499, dtype: object

# %% [markdown]
# Valores Nulos

# %%
filtro_nulos = pd.isnull(df['taster_name'])
df[filtro_nulos].shape
# Out:
# (13643, 15)

# %%
df['tester_name'] = df['taster_name'].fillna('Juan')
df['tester_name'].value_counts()
# Out:
# tester_name
# Juan                  13643
# Roger Voss            13045
# Michael Schachner      7752
# Kerin O’Keefe          5313
# Paul Gregutt           4851
# Virginie Boone         4696
# Matt Kettmann          3035
# Joe Czerwinski         2605
# Sean P. Sullivan       2358
# Anna Lee C. Iijima     2134
# Jim Gordon             2032
# Anne Krebiehl MW       1769
# Lauren Buzzeo           938
# Susan Kostrzewa         593
# Jeff Jenssen            234
# Mike DeSimone           231
# Alexander Peartree      210
# Carrie Dykes             45
# Fiona Adams              11
# Christina Pickard         4
# Name: count, dtype: int64

# %%
filtro = (df['taster_name'] == 'Roger Voss')
df[filtro].points.mean()
# Out:
# np.float64(88.6789574549636)
