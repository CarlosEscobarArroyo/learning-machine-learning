# %% [markdown]
# # Feature engineering

# %%
import pandas as pd
data = pd.read_csv("/wine.csv")

# %%
from exploration import explore

explore.obtener_tipo_datos(data)
# Out:
# (['Unnamed: 0', 'points', 'price'],
#  ['country',
#   'description',
#   'designation',
#   'province',
#   'region_1',
#   'region_2',
#   'taster_name',
#   'taster_twitter_handle',
#   'title',
#   'variety',
#   'winery'])

# %%
explore.show_barplot(data['points'],data['price'], data)

# %%
data_peru = data[data['variety'] == 'Red Blend']
explore.plot_boxplot(data_peru['country'], data_peru['price'], data_peru)

# %%
explore.plot_scatter(data_peru['country'], data_peru['points'], data_peru)

# %%
explore.plot_correlation(data[['points', 'price']])

# %%
data = pd.read_csv("titanic.csv")

# %%
numdata, stringdata = explore.obtener_tipo_datos(data)

# %%
numdata
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
explore.plot_correlation(data[numdata])
