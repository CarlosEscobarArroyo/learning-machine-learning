# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv("all_stocks_5yr.csv")

# %%
data.head()
# Out:
#    index       date   open   high    low  close    volume Name  day
# 0      0 2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL    0
# 1      1 2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL    3
# 2      2 2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL    4
# 3      3 2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL    5
# 4      4 2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL    6

# %%
data.Name.value_counts()
# Out:
# Name
# ZTS     1259
# AAL     1259
# AAPL    1259
# AAP     1259
# ABBV    1259
#         ...
# DXC      215
# BHGE     152
# BHF      143
# DWDP     109
# APTV      44
# Name: count, Length: 505, dtype: int64

# %%
data['date'] = pd.to_datetime(data['date'], format="%Y-%m-%d")
# Out:
# C:\Users\profl3402\AppData\Local\Temp\ipykernel_18584\3795902732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['date'] = pd.to_datetime(data['date'], format="%Y-%m-%d")

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# variables = ["date", "open", "high", "low", "close", "volume"]


data = data.reset_index()

data['day'] = (data['date'] - data['date'].min()).dt.days

data2 = data[data['Name'] == "AAPL"]

X = data2[['day']].values
Y = data2[['close']].values

print(len(X))
print(len(Y))

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# 1259
# 1259
# LinearRegression()

# %%
model.score(X_test, Y_test)
# Out:
# 0.7709792918464854
